# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import scrapbook as sb 
import pandas as pd
from IPython.display import TextDisplayObject

# %% [markdown]
# ## Regression Dataset

# %%
book = sb.read_notebooks('/Users/manasigude/Academics/Project(ABC_GAN)/ABC_GAN/Regression')

# %%
data = []
for nb in book.notebooks:
    nbList = [nb.papermill_dataframe.iloc[1]['value'],
              nb.papermill_dataframe.iloc[2]['value'],
              nb.papermill_dataframe.iloc[0]['value'],
              nb.papermill_dataframe.iloc[3]['value'],
              nb.scraps['Stats Model MSE'].data,
              nb.scraps['GAN Model MSE'].data,
              nb.scraps['ABC-GAN Model MSE'].data,
              nb.scraps['Stats Model MAE'].data,
              nb.scraps['GAN Model MAE'].data,
              nb.scraps['ABC-GAN Model MAE'].data,
              nb.scraps['Stats Model Manhattan Distance'].data,
              nb.scraps['GAN Model Manhattan Distance'].data,
              nb.scraps['ABC-GAN Model Manhattan Distance'].data,
              nb.scraps['Stats Model Euclidean distance'].data,
              nb.scraps['GAN Model Euclidean distance'].data,
              nb.scraps['ABC-GAN Model Euclidean distance'].data,
              nb.scraps['GAN Model n_epochs'].data,
              nb.scraps['ABC-GAN Model n_epochs'].data]        
    data.append(nbList)
df = pd.DataFrame(data, columns = ['Features','Sample Size','Mean','Variance',
                                   'Stats Model MSE','GAN MSE','ABC-GAN MSE',
                                   'Stats Model MAE','GAN MAE','ABC-GAN MAE',
                                   'Stats Manhattan Distance','GAN Manhattan Distance','ABC-GAN Manhattan Distance',
                                   'Stats Model Euclidean Distance','GAN Euclidean Distance','ABC-GAN Euclidean Distance',
                                    'GAN Model n_epochs,ABC-GAN Model n_epochs'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/5x/0vb7l3qn55q_tgn_2zh9s0bw0000gn/T/ipykernel_14665/676516387.py in <module>
#       7               nb.scraps['Stats Model MSE'].data,
#       8               nb.scraps['GAN Model MSE'].data,
# ----> 9               nb.scraps['ABC-GAN Model MSE'].data,
#      10               nb.scraps['Stats Model MAE'].data,
#      11               nb.scraps['GAN Model MAE'].data,
#
# KeyError: 'ABC-GAN Model MSE'

# %%
df
# Out:
#     Features  Sample Size  Mean  Variance  Stats Model MSE   GAN MSE  \
# 0       10.0         10.0   1.0      1.00     7.918076e-31  0.001292
# 1       10.0         10.0   1.0      0.10     4.939612e-30  0.002573
# 2       10.0        100.0   0.0      0.10     3.640551e-07  0.000866
# 3       10.0        100.0   0.0      0.01     2.470461e-07  0.000712
# 4       10.0         10.0   1.0      0.01     1.797374e-30  0.001048
# 5       10.0         10.0   0.0      1.00     1.461054e-30  0.249578
# 6       10.0         10.0   0.0      0.10     3.452268e-30  0.001052
# 7       10.0         10.0   0.0      0.01     1.735826e-30  0.321958
# 8       10.0        100.0   1.0      1.00     1.746527e-07  0.000986
# 9       10.0        100.0   1.0      0.10     2.394029e-07  0.000702
# 10      10.0        100.0   1.0      0.01     1.378492e-07  0.000961
# 11      10.0        100.0   0.0      1.00     2.322160e-07  0.000879
#
#     ABC-GAN MSE  Stats Model MAE   GAN MAE  ABC-GAN MAE  \
# 0      0.002614     7.896461e-16  0.027954     0.036596
# 1      0.117498     2.029280e-15  0.039422     0.257083
# 2      0.000911     4.860682e-04  0.023569     0.023437
# 3      0.000868     3.943812e-04  0.021341     0.023695
# 4      0.001210     1.228184e-15  0.026799     0.028451
# 5      0.001358     1.041528e-15  0.415077     0.026388
# 6      0.355005     1.645906e-15  0.026742     0.453102
# 7      0.000921     1.006834e-15  0.416768     0.025534
# 8      0.000847     3.293122e-04  0.025878     0.022023
# 9      0.000977     3.847282e-04  0.020451     0.025443
# 10     0.000735     2.915312e-04  0.024163     0.021250
# 11     0.002064     3.861832e-04  0.022863     0.033541
#
#     Stats Manhattan Distance  GAN Manhattan Distance  \
# 0               7.896461e-15                0.279537
# 1               2.029280e-14                0.394223
# 2               4.860682e-02                2.356935
# 3               3.943812e-02                2.134113
# 4               1.228184e-14                0.267987
# 5               1.041528e-14                4.150769
# 6               1.645906e-14                0.267423
# 7               1.006834e-14                4.167685
# 8               3.293122e-02                2.587777
# 9               3.847282e-02                2.045142
# 10              2.915312e-02                2.416255
# 11              3.861832e-02                2.286302
#
#     ABC-GAN Manhattan Distance  Stats Model Euclidean Distance  \
# 0                     0.365959                    2.813908e-15
# 1                     2.570828                    7.028237e-15
# 2                     2.343704                    6.033698e-03
# 3                     2.369544                    4.970373e-03
# 4                     0.284513                    4.239545e-15
# 5                     0.263882                    3.822373e-15
# 6                     4.531017                    5.875600e-15
# 7                     0.255338                    4.166325e-15
# 8                     2.202254                    4.179147e-03
# 9                     2.544314                    4.892882e-03
# 10                    2.125036                    3.712805e-03
# 11                    3.354146                    4.818880e-03
#
#     GAN Euclidean Distance  ABC-GAN Euclidean Distance
# 0                 0.112206                    0.157957
# 1                 0.157165                    1.082867
# 2                 0.294128                    0.301400
# 3                 0.266821                    0.294534
# 4                 0.099721                    0.109749
# 5                 1.578582                    0.115923
# 6                 0.102217                    1.883882
# 7                 1.793571                    0.095933
# 8                 0.313942                    0.287325
# 9                 0.264806                    0.312137
# 10                0.309927                    0.269728
# 11                0.296373                    0.449918

# %% [markdown]
# ## Friedman1 Dataset

# %%
book = sb.read_notebooks('/Users/manasigude/Academics/Project(ABC_GAN)/ABC_GAN/Friedman1')

# %%
data = []
for nb in book.notebooks:
    nbList = [nb.papermill_dataframe.iloc[1]['value'],
              nb.papermill_dataframe.iloc[2]['value'],
              nb.papermill_dataframe.iloc[0]['value'],
              nb.papermill_dataframe.iloc[3]['value'],
              nb.scraps['Stats Model MSE'].data,
              nb.scraps['GAN Model MSE'].data,
              nb.scraps['ABC-GAN Model MSE'].data,
              nb.scraps['Stats Model MAE'].data,
              nb.scraps['GAN Model MAE'].data,
              nb.scraps['ABC-GAN Model MAE'].data,
              nb.scraps['Manhattan Distance'].data,
              nb.scraps['GAN Model Manhattan Distance'].data,
              nb.scraps['ABC-GAN Model Manhattan Distance'].data,
              nb.scraps['Euclidean distance'].data,
              nb.scraps['GAN Model Euclidean distance'].data,
              nb.scraps['ABC-GAN Model Euclidean distance'].data]        
    data.append(nbList)
df = pd.DataFrame(data, columns = ['Features','Sample Size','Mean','Variance',
                                   'Stats Model MSE','GAN MSE','ABC-GAN MSE',
                                   'Stats Model MAE','GAN MAE','ABC-GAN MAE',
                                   'Stats Manhattan Distance','GAN Manhattan Distance','ABC-GAN Manhattan Distance',
                                   'Stats Model Euclidean Distance','GAN Euclidean Distance','ABC-GAN Euclidean Distance'])

# %%
df
# Out:
#     Features  Sample Size  Mean  Variance  Stats Model MSE   GAN MSE  \
# 0       10.0         10.0   1.0      1.00     2.745591e-30  0.000801
# 1       10.0         10.0   1.0      0.10     1.290912e-30  0.001210
# 2       10.0        100.0   0.0      0.10     2.070649e-01  0.067001
# 3       10.0        100.0   0.0      0.01     2.840579e-01  0.224470
# 4       10.0         10.0   1.0      0.01     1.749053e-30  0.054152
# 5       10.0         10.0   0.0      1.00     1.758798e-30  0.001472
# 6       10.0         10.0   0.0      0.10     1.148822e-30  0.081498
# 7       10.0         10.0   0.0      0.01     2.848219e-30  0.023195
# 8       10.0        100.0   1.0      1.00     1.475633e-01  0.000960
# 9       10.0        100.0   1.0      0.10     1.863879e-01  0.213209
# 10      10.0        100.0   1.0      0.01     3.114623e-01  0.045839
# 11      10.0        100.0   0.0      1.00     2.748213e-01  0.014215
#
#     ABC-GAN MSE  Stats Model MAE   GAN MAE  ABC-GAN MAE  \
# 0      0.001304     1.410677e-15  0.020341     0.029244
# 1      0.024601     9.686696e-16  0.022876     0.120296
# 2      0.000926     3.278025e-01  0.106161     0.022124
# 3      0.091630     4.092797e-01  0.172053     0.155386
# 4      0.000796     1.143530e-15  0.178297     0.023277
# 5      0.000821     9.131584e-16  0.028243     0.021220
# 6      0.058318     8.236467e-16  0.254737     0.168395
# 7      0.038681     1.493250e-15  0.131344     0.163005
# 8      0.000992     3.094022e-01  0.024968     0.023886
# 9      0.000987     3.358884e-01  0.180766     0.024254
# 10     0.090388     4.141847e-01  0.051066     0.127542
# 11     0.001074     4.024432e-01  0.038336     0.024039
#
#     Stats Manhattan Distance  GAN Manhattan Distance  \
# 0               1.410677e-14                0.203407
# 1               9.686696e-15                0.228760
# 2               3.278025e+01               10.616071
# 3               4.092797e+01               17.205320
# 4               1.143530e-14                1.782967
# 5               9.131584e-15                0.282426
# 6               8.236467e-15                2.547369
# 7               1.493250e-14                1.313442
# 8               3.094022e+01                2.496792
# 9               3.358884e+01               18.076585
# 10              4.141847e+01                5.106582
# 11              4.024432e+01                3.833567
#
#     ABC-GAN Manhattan Distance  Stats Model Euclidean Distance  \
# 0                     0.292437                    5.239839e-15
# 1                     1.202956                    3.592927e-15
# 2                     2.212369                    4.550438e+00
# 3                    15.538605                    5.329708e+00
# 4                     0.232769                    4.182168e-15
# 5                     0.212205                    4.193802e-15
# 6                     1.683953                    3.389428e-15
# 7                     1.630047                    5.336871e-15
# 8                     2.388578                    3.841397e+00
# 9                     2.425376                    4.317266e+00
# 10                   12.754193                    5.580881e+00
# 11                    2.403899                    5.242340e+00
#
#     GAN Euclidean Distance  ABC-GAN Euclidean Distance
# 0                 0.088335                    0.113902
# 1                 0.109555                    0.495896
# 2                 2.588300                    0.304154
# 3                 4.737828                    3.027032
# 4                 0.734964                    0.089032
# 5                 0.119289                    0.089257
# 6                 0.901828                    0.753667
# 7                 0.480979                    0.621660
# 8                 0.309727                    0.313998
# 9                 4.617435                    0.314055
# 10                2.141003                    3.006454
# 11                1.192237                    0.327060

# %%
nb = sb.read_notebook('/Users/manasigude/Academics/Project(ABC_GAN)/ABC_GAN/Test.ipynb')

# %%
fig = nb.scraps['Chart1'].display['data']

# %%
display(fig,raw=True)
