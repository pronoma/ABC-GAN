# %% [markdown]
# # Dataset 1 - Regression

# %% [markdown]
# ## Experiment Details
#
# The aim of the experiment is to verify if the:
# 1. ABC_GAN model corrects model misspecification
# 2. ABC_GAN model performs better and converges faster than a simple C-GAN model
#
# In the experiment we predict the distribution that represents the real data and simulate realistic fake data points
# using statistical mode, C-GAN and ABC-GAN model with 3 priors. We analyze and compare their performance using metrics like mean squared error, mean absolute error , manhattan distance and euclidean distance between $y_{real}$ and $y_{pred}$
#
# The models are as follows:
#
# 1. The statistical model assumes the distribution $Y=\beta X + \mu$ where $\mu \sim N(0,1)$
# 2. The Conditional GAN consists of
#     1. Generator with 2 hidden layers with 100 nodes each and ReLu activation.
#     2. Discriminator with 2 hidden layers with 25 and 50 nodes and ReLu activation.
#     We use Adam's optimser and BCE Logit Loss to train the model. The input to the Generator of the GAN is (x,e) where x are the features and $e \sim N(0,1)$. The discriminator output is linear.
# 3. The ABC GAN Model consists of
#     1. ABC generator is defined as follows:
#         1. $Y = 1 + \beta_1 x_1 + \beta_2 x_2 + \beta_2 x_3 + ... + \beta_n x_n + N(0,\sigma)$ where $\sigma = 0.1$
#         2. $\beta_i \sim N(0,\sigma^{*})$ when $\mu = 0$ else $\beta_i \sim N(\beta_i^{*},\sigma^{*})$ where $\beta_i^{*}s$ are coefficients obtained from statistical model
#         3. $\sigma^{*}$ takes the values 0.01,0.1 and 1
#     2. C-GAN network is as defined above. However the input to the Generator of the GAN is $(x,y_{abc})$ where $y_{abc}$ is the output of the ABC Generator.

# %% [markdown]
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import train_test
import ABC_train_test
import regressionDataset
import network
import statsModel
import performanceMetrics
import dataset
import sanityChecks
import torch 
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy.stats import norm
from torch.utils.data import Dataset,DataLoader 
from torch import nn

# %% [markdown]
# ## Parameters
#
# General Parameters
#
# 1. Number of Samples
# 2. Number of features
#
# ABC-Generator parameters are as mentioned below:
# 1. mean : 1 ($\beta \sim N(\beta^{*},\sigma)$ where $\beta^{*}$ are coefficients of statistical model) or 1 ($\beta \sim N(0,\sigma)$
# 2. std : $\sigma = 1, 0.1 , 0.01$ (standard deviation)

# %%
n_features = 10
n_samples= 100
 
#ABC Generator Parameters
mean = 1 
variance = 0.001

# %% [markdown]
# ## Dataset

# %% [markdown]
# Generate a random regression problem
#
# $Y = 1 + \beta_1 x_1 + \beta_2 x_2 + \beta_2 x_3 + ... + \beta_n x_n + N(0,\sigma)$ where $\sigma = 0.1$

# %%
X,Y = regressionDataset.regression_data(n_samples,n_features)
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  2.004289 -0.010676  0.139537 -0.179802 -1.680115 -1.104910  0.337248
# 1 -0.566131 -0.794050 -0.322668  0.242641  0.291463 -0.001148  0.457830
# 2 -0.084200 -0.532431 -0.364982 -2.553321 -0.833493  0.742069  0.651009
# 3  0.653824  0.153772  1.216998 -0.584579  0.081441 -1.136030  0.190964
# 4 -1.166797 -0.241216 -0.873991  0.361352  0.553853 -0.236745 -0.071427
#
#          X8        X9       X10           Y
# 0  0.815548  0.098597  0.884465  161.274489
# 1  0.212839 -2.430865  0.035155  -15.116698
# 2 -1.071123 -0.317187 -0.931812 -142.853377
# 3  1.112000 -1.055738  1.251325  159.120549
# 4 -0.562435 -0.407079  0.648010 -105.305452

# %% [markdown]
# ## Stats Model

# %%
[coeff,y_pred] = statsModel.statsModel(X,Y)
# Out:
# No handles with labels found to put in legend.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.480e+07
# Date:                Tue, 19 Oct 2021   Prob (F-statistic):          9.07e-289
# Time:                        20:55:12   Log-Likelihood:                 617.05
# No. Observations:                 100   AIC:                            -1212.
# Df Residuals:                      89   BIC:                            -1183.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.776e-17   5.36e-05  -5.18e-13      1.000      -0.000       0.000
# x1             0.3488   5.76e-05   6055.304      0.000       0.349       0.349
# x2             0.1666   5.59e-05   2978.322      0.000       0.166       0.167
# x3             0.0531   5.61e-05    946.338      0.000       0.053       0.053
# x4             0.0809   5.51e-05   1468.536      0.000       0.081       0.081
# x5             0.1484   5.67e-05   2617.073      0.000       0.148       0.148
# x6             0.5368   5.57e-05   9636.812      0.000       0.537       0.537
# x7             0.4299   5.56e-05   7727.965      0.000       0.430       0.430
# x8             0.5123   5.49e-05   9339.775      0.000       0.512       0.512
# x9             0.0512   5.47e-05    935.999      0.000       0.051       0.051
# x10            0.4517   5.57e-05   8115.725      0.000       0.452       0.452
# ==============================================================================
# Omnibus:                        2.981   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.225   Jarque-Bera (JB):                2.904
# Skew:                          -0.410   Prob(JB):                        0.234
# Kurtosis:                       2.844   Cond. No.                         1.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Parameters:  const   -2.775558e-17
# x1       3.488042e-01
# x2       1.665651e-01
# x3       5.311412e-02
# x4       8.089261e-02
# x5       1.483685e-01
# x6       5.368406e-01
# x7       4.298701e-01
# x8       5.123106e-01
# x9       5.115365e-02
# x10      4.516853e-01
# dtype: float64
# Performance Metrics
# Mean Squared Error: 2.557799040321699e-07
# Mean Absolute Error: 0.0004185583111347456
# Manhattan distance: 0.04185583111347456
# Euclidean distance: 0.00505746877431952

# %% [markdown]
# ## Common Training Parameters (GAN & ABC_GAN)

# %%
n_epochs = 5000
error = 0.001
batch_size = n_samples//2

# %% [markdown]
# ## GAN Model

# %%
real_dataset = dataset.CustomDataset(X,Y)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# **Training GAN for n_epochs number of epochs**

# %%
generator = network.Generator(n_features+2)
discriminator = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(generator.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
print(generator)
print(discriminator)
# Out:
# Generator(
#   (hidden1): Linear(in_features=12, out_features=100, bias=True)
#   (hidden2): Linear(in_features=100, out_features=100, bias=True)
#   (output): Linear(in_features=100, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Discriminator(
#   (hidden1): Linear(in_features=12, out_features=25, bias=True)
#   (hidden2): Linear(in_features=25, out_features=50, bias=True)
#   (output): Linear(in_features=50, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
train_test.training_GAN(discriminator,generator,disc_opt,gen_opt,real_dataset,batch_size, n_epochs,criterion,device)

# %%
train_test.test_generator(generator,real_dataset,device)
# Out:
# Mean Square Error: 0.0001960896850781766
# Mean Absolute Error: 0.010741096860505641
# Mean Manhattan Distance: 1.0741096860505641
# Mean Euclidean Distance: 0.14002304058875825

# %%
sanityChecks.discProbVsError(real_dataset,discriminator,device)

# %% [markdown]
# **Training GAN until mse of y_pred is > 0.1 or n_epochs < 30000**

# %%
generator = network.Generator(n_features+2)
discriminator = network.Discriminator(n_features+2)
criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(generator.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
train_test.training_GAN_2(discriminator,generator,disc_opt,gen_opt,real_dataset,batch_size,error,criterion,device)
# Out:
# Number of epochs needed 291

# %%
train_test.test_generator(generator,real_dataset,device)
# Out:
# Mean Square Error: 0.0005985823053776704
# Mean Absolute Error: 0.01972659948123619
# Mean Manhattan Distance: 1.972659948123619
# Mean Euclidean Distance: 0.2446384443708191

# %% [markdown]
# # ABC GAN Model

# %% [markdown]
# ### Training the network
# **Training ABC-GAN for n_epochs number of epochs**

# %%
gen = network.Generator(n_features+2)
disc = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(gen.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(disc.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
ABC_train_test.training_GAN(disc, gen,disc_opt,gen_opt,real_dataset, batch_size, n_epochs,criterion,coeff,mean,variance,device)

# %%
ABC_train_test.test_generator(gen,real_dataset,coeff,mean,variance,device)
# Out:
# Mean Square Error: 0.0001236869310732247
# Mean Absolute Error: 0.008726322259232401
# Mean Manhattan Distance: 0.8726322259232402
# Mean Euclidean Distance: 0.11116835760474271

# %% [markdown]
# #### Sanity Checks

# %%
sanityChecks.discProbVsError(real_dataset,disc,device)

# %% [markdown]
# **Training GAN until mse of y_pred is > 0.1 or n_epochs < 30000**

# %%
gen = network.Generator(n_features+2)
disc = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(gen.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(disc.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
ABC_train_test.training_GAN_2(disc,gen,disc_opt,gen_opt,real_dataset,batch_size, error,criterion,coeff,mean,variance,device)
# Out:
# Number of epochs 275

# %%
ABC_train_test.test_generator(gen,real_dataset,coeff,mean,variance,device)
# Out:
# Mean Square Error: 0.0009823769090412527
# Mean Absolute Error: 0.025833445964939892
# Mean Manhattan Distance: 2.583344596493989
# Mean Euclidean Distance: 0.3134191893986425
