# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [14]</a>'.</span>

# %% [markdown]
# # Dataset 1 - Regression

# %% [markdown]
# ## Experiment Details
#
# The aim of the experiment is to verify if the:
# 1. ABC_GAN model corrects model misspecification
# 2. ABC_GAN model performs better and converges faster than a simple C-GAN model
#
# In the experiment we predict the distribution that represents the real data and simulate realistic fake data points
# using statistical mode, C-GAN and ABC-GAN model with 3 priors. We analyze and compare their performance using metrics like mean squared error, mean absolute error , manhattan distance and euclidean distance between $y_{real}$ and $y_{pred}$
#
# The models are as follows:
#
# 1. The statistical model assumes the distribution $Y=\beta X + \mu$ where $\mu \sim N(0,1)$
# 2. The Conditional GAN consists of
#     1. Generator with 2 hidden layers with 100 nodes each and ReLu activation.
#     2. Discriminator with 2 hidden layers with 25 and 50 nodes and ReLu activation.
#     We use Adam's optimser and BCE Logit Loss to train the model. The input to the Generator of the GAN is (x,e) where x are the features and $e \sim N(0,1)$. The discriminator output is linear.
# 3. The ABC GAN Model consists of
#     1. ABC generator is defined as follows:
#         1. $Y = 1 + \beta_1 x_1 + \beta_2 x_2 + \beta_2 x_3 + ... + \beta_n x_n + N(0,\sigma)$ where $\sigma = 0.1$
#         2. $\beta_i \sim N(0,\sigma^{*})$ when $\mu = 0$ else $\beta_i \sim N(\beta_i^{*},\sigma^{*})$ where $\beta_i^{*}s$ are coefficients obtained from statistical model
#         3. $\sigma^{*}$ takes the values 0.01,0.1 and 1
#     2. C-GAN network is as defined above. However the input to the Generator of the GAN is $(x,y_{abc})$ where $y_{abc}$ is the output of the ABC Generator.

# %% [markdown]
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import train_test
import ABC_train_test
import regressionDataset
import network
import statsModel
import performanceMetrics
import dataset
import sanityChecks
import torch 
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy.stats import norm
from torch.utils.data import Dataset,DataLoader 
from torch import nn

# %% [markdown]
# ## Parameters
#
# General Parameters
#
# 1. Number of Samples
# 2. Number of features
#
# ABC-Generator parameters are as mentioned below:
# 1. mean : 1 ($\beta \sim N(\beta^{*},\sigma)$ where $\beta^{*}$ are coefficients of statistical model) or 1 ($\beta \sim N(0,\sigma)$
# 2. std : $\sigma = 1, 0.1 , 0.01$ (standard deviation)

# %%
n_features = 10
n_samples= 100
 
#ABC Generator Parameters
mean = 1 
variance = 0.001

# %%
# Parameters
n_samples = 10
n_features = 10
mean = 1
variance = 1

# %% [markdown]
# ## Dataset

# %% [markdown]
# Generate a random regression problem
#
# $Y = 1 + \beta_1 x_1 + \beta_2 x_2 + \beta_2 x_3 + ... + \beta_n x_n + N(0,\sigma)$ where $\sigma = 0.1$

# %%
X,Y = regressionDataset.regression_data(n_samples,n_features)
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.171964  1.157452 -1.404566  0.534203  0.836316 -2.566755 -1.201416
# 1  0.102507 -0.277837  0.927376 -0.375743 -0.789372  0.478594 -0.556309
# 2 -1.101391  0.124528 -0.467261  0.288532  2.418243  1.120863 -0.790069
# 3  0.971302 -0.745631 -1.142588  1.425357 -1.587189  1.071775  1.115553
# 4 -0.483492  1.864656 -0.391644  0.191828 -1.040680 -0.561578  0.710468
#
#          X8        X9       X10           Y
# 0 -0.300945  0.250517 -0.229282 -161.421694
# 1  0.343902  0.769301  0.169832   83.733056
# 2  0.084912  0.863123 -0.130902  248.228580
# 3  0.593979  1.197912  1.188860   42.746828
# 4  1.693233  1.298221  0.596869   87.393826

# %% [markdown]
# ## Stats Model

# %%
[coeff,y_pred] = statsModel.statsModel(X,Y)
# Out:
# No handles with labels found to put in legend.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 19 Oct 2021   Prob (F-statistic):                nan
# Time:                        20:27:41   Log-Likelihood:                 322.21
# No. Observations:                  10   AIC:                            -624.4
# Df Residuals:                       0   BIC:                            -621.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -2.22e-16        inf         -0        nan         nan         nan
# x1             0.0357        inf          0        nan         nan         nan
# x2             0.2723        inf          0        nan         nan         nan
# x3             0.4864        inf          0        nan         nan         nan
# x4             0.1482        inf          0        nan         nan         nan
# x5             0.7872        inf          0        nan         nan         nan
# x6             0.6413        inf          0        nan         nan         nan
# x7             0.0719        inf          0        nan         nan         nan
# x8             0.1643        inf          0        nan         nan         nan
# x9             0.3584        inf          0        nan         nan         nan
# x10            0.1595        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.351   Durbin-Watson:                   2.401
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                0.991
# Skew:                           0.600   Prob(JB):                        0.609
# Kurtosis:                       2.031   Cond. No.                         6.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# Parameters:  const   -2.220446e-16
# x1       3.574489e-02
# x2       2.722575e-01
# x3       4.864406e-01
# x4       1.481796e-01
# x5       7.871876e-01
# x6       6.412768e-01
# x7       7.192321e-02
# x8       1.643155e-01
# x9       3.584076e-01
# x10      1.595193e-01
# dtype: float64
# Performance Metrics
# Mean Squared Error: 6.040332603180576e-30
# Mean Absolute Error: 1.9984014443252818e-15
# Manhattan distance: 1.9984014443252818e-14
# Euclidean distance: 7.771957670484686e-15

# %% [markdown]
# ## Common Training Parameters (GAN & ABC_GAN)

# %%
n_epochs = 5000
error = 0.001
batch_size = n_samples//2

# %% [markdown]
# ## GAN Model

# %%
real_dataset = dataset.CustomDataset(X,Y)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# **Training GAN for n_epochs number of epochs**

# %%
generator = network.Generator(n_features+2)
discriminator = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(generator.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
print(generator)
print(discriminator)
# Out:
# Generator(
#   (hidden1): Linear(in_features=12, out_features=100, bias=True)
#   (hidden2): Linear(in_features=100, out_features=100, bias=True)
#   (output): Linear(in_features=100, out_features=1, bias=True)
#   (relu): ReLU()
# )
# Discriminator(
#   (hidden1): Linear(in_features=12, out_features=25, bias=True)
#   (hidden2): Linear(in_features=25, out_features=50, bias=True)
#   (output): Linear(in_features=50, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
train_test.training_GAN(discriminator,generator,disc_opt,gen_opt,real_dataset,batch_size, n_epochs,criterion,device)

# %%
train_test.test_generator(generator,real_dataset,device)
# Out:
# Mean Square Error: 0.04102613560519467
# Mean Absolute Error: 0.17150807048939168
# Mean Manhattan Distance: 1.715080704893917
# Mean Euclidean Distance: 0.6397670193058254

# %%
sanityChecks.discProbVsError(real_dataset,discriminator,device)

# %% [markdown]
# **Training GAN until mse of y_pred is > 0.1 or n_epochs < 30000**

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
generator = network.Generator(n_features+2)
discriminator = network.Discriminator(n_features+2)
criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(generator.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=0.01, betas=(0.5, 0.999))

train_test.training_GAN_2(discriminator,generator,disc_opt,gen_opt,real_dataset,batch_size,error,criterion,device)
# Out:
# Number of epochs needed 30000

# %%
train_test.test_generator(generator,real_dataset,device)
# Out:
# Mean Square Error: 0.03390987738653216
# Mean Absolute Error: 0.14498432619571686
# Mean Manhattan Distance: 1.4498432619571686
# Mean Euclidean Distance: 0.5821703203395894

# %% [markdown]
# # ABC GAN Model

# %% [markdown]
# ### Training the network
# **Training ABC-GAN for n_epochs number of epochs**

# %%
gen = network.Generator(n_features+2)
disc = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(gen.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(disc.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
ABC_train_test.training_GAN(disc, gen,disc_opt,gen_opt,real_dataset, batch_size, n_epochs,criterion,coeff,mean,variance,device)

# %%
ABC_train_test.test_generator(gen,real_dataset,coeff,mean,variance,device)
# Out:
# Mean Square Error: 0.0013364894963355282
# Mean Absolute Error: 0.029340097607672214
# Mean Manhattan Distance: 0.29340097607672216
# Mean Euclidean Distance: 0.11162853141110486

# %% [markdown]
# #### Sanity Checks

# %%
sanityChecks.discProbVsError(real_dataset,disc,device)

# %% [markdown]
# **Training GAN until mse of y_pred is > 0.1 or n_epochs < 30000**

# %%
gen = network.Generator(n_features+2)
disc = network.Discriminator(n_features+2)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(gen.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(disc.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
train_test.training_GAN_2(disc,gen,disc_opt,gen_opt,real_dataset,batch_size,error,criterion,device)
# Out:
# Number of epochs needed 365

# %%
ABC_train_test.test_generator(gen,real_dataset,coeff,mean,variance,device)
# Out:
# Mean Square Error: 0.01641072358809089
# Mean Absolute Error: 0.06417505103610456
# Mean Manhattan Distance: 0.6417505103610456
# Mean Euclidean Distance: 0.33730566811830254
