# %% [markdown]
# ## Import Libraries

# %%
import train_test
import ABC_train_test
import linearDataset
import network
import statsModel
import performanceMetrics
import dataset
import sanityChecks
import torch 
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy.stats import norm
from torch.utils.data import Dataset,DataLoader 
from torch import nn
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset

# %% [markdown]
# Generate the linear dataset
#
# $y=m*x + c + e$ where $m=1$, $c=0.5$ and $e \sim N(0,1)$

# %%
n_samples = 100
n_features = 1

# %%
X,Y = linearDataset.linear_data(n_samples)
# Out:
#           X         Y
# 0  0.430640  0.298948
# 1  0.088912  0.543568
# 2 -0.229772 -1.278349
# 3  0.462806  1.821707
# 4 -0.045914 -0.800436

# %% [markdown]
# ## Stats Model

# %% [markdown]
# The statistical model is assumed to be $Y=\beta X + \mu$ where $\mu \sim N(0,1)$

# %%
[coeff,y_pred] = statsModel.statsModel(X,Y)
# Out:
# No handles with labels found to put in legend.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.059
# Model:                            OLS   Adj. R-squared (uncentered):              0.050
# Method:                 Least Squares   F-statistic:                              6.229
# Date:                Tue, 05 Oct 2021   Prob (F-statistic):                      0.0142
# Time:                        18:32:16   Log-Likelihood:                         -138.84
# No. Observations:                 100   AIC:                                      279.7
# Df Residuals:                      99   BIC:                                      282.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.2433      0.097      2.496      0.014       0.050       0.437
# ==============================================================================
# Omnibus:                        3.070   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.215   Jarque-Bera (JB):                2.917
# Skew:                          -0.416   Prob(JB):                        0.233
# Kurtosis:                       2.908   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Parameters:  x1    0.243292
# dtype: float64
# Performance Metrics
# Mean Squared Error: 0.9408088334294514
# Mean Absolute Error: 0.7707244604596329
# Manhattan distance: 77.07244604596326
# Euclidean distance: 9.699530057840182

# %% [markdown]
# ## Generator and Discriminator Networks

# %%
#Discriminator Parameters 
hidden_nodes = 25 
#ABC Generator Parameters
mean = 1 
variance = 0.001

# %% [markdown]
# **Generator Model**

# %%
class Generator(nn.Module):

  def __init__(self,n_input):
    super().__init__()
    self.output = nn.Linear(n_input,1)

  def forward(self, x):
    x = self.output(x)
    return x

# %% [markdown]
# **Discriminator Model**

# %%
class Discriminator(nn.Module):
  def __init__(self,n_input,n_hidden):

    super().__init__()
    self.hidden = nn.Linear(n_input,n_hidden)
    self.output = nn.Linear(n_hidden,1)
    self.relu = nn.ReLU()

  def forward(self, x):
    x = self.hidden(x)
    x = self.relu(x)
    x = self.output(x)
    return x

# %% [markdown]
# **ABC Generators**

# %% [markdown]
# 1. *Correctly Specified Prior* : The 1st ABC Generator is defined as $Y = m*X + c + e$ where $m \sim N(1,1)$ , $c=0.5$ and $e \sim N(0,1)$
# 2. *Misspecified Prior* : The 2nd ABC Generator is defined as $Y = 1 + m*X + c + e$ where $m \sim N(1,1)$ , $c=0.5$ and $e \sim N(0,1)$

# %% [markdown]
# ## GAN Model

# %%
real_dataset = dataset.CustomDataset(X,Y)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
generator = Generator(n_features+1)
discriminator = Discriminator(n_features+1,hidden_nodes)

criterion = torch.nn.BCEWithLogitsLoss()
gen_opt = torch.optim.Adam(generator.parameters(), lr=0.01, betas=(0.5, 0.999))
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=0.01, betas=(0.5, 0.999))

# %%
n_epochs = 5000
batch_size = n_samples//2

# %%
train_test.training_GAN(disc, gen,disc_opt,gen_opt,dataset, batch_size, n_epochs,criterion,device)

# %%
train_test.test_generator(generator,real_dataset,device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5x/0vb7l3qn55q_tgn_2zh9s0bw0000gn/T/ipykernel_6348/41052246.py in <module>
# ----> 1 train_test.test_generator(generator,real_dataset,device)
#
# ~/Academics/Project(ABC_GAN)/ABC_GAN/src/train_test.py in test_generator(gen, dataset, device)
#     121     for x_batch, y_batch in test_loader:
#     122       z= np.random.normal(0,1,size=(len(dataset),1))
# --> 123       gen_input = torch.cat((x_batch,z),dim=1).to(device)
#     124       generated_y = gen(gen_input)
#     125       generated_y = generated_y.cpu().detach()
#
# TypeError: expected Tensor as element 1 in argument 0, but got numpy.ndarray
