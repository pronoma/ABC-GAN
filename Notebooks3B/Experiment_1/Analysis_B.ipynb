# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import scrapbook as sb 
import pandas as pd
import numpy as np 
import seaborn as sns 
import numpy as np
from statistics import mean, median
import matplotlib.pyplot as plt

# %%
book = sb.read_notebooks("./GAN_Output")
gan_data = []
gan_mse = []
for nb in book.notebooks:
    metrics = nb.scraps['GAN_1 Metrics'].data
    for i in range(1000):
        gan_mse.append(metrics[0][i])
    nbList = [nb.scraps['GAN Model MSE'].data,
              nb.scraps['GAN Model MAE'].data,
              nb.scraps['GAN Model Euclidean distance'].data,
              nb.scraps['GAN Model Manhattan Distance'].data]        
    gan_data.append(nbList)
    
df = pd.DataFrame(gan_data, columns = ['MSE','MAE','Euclidean Distance','Manhattan Distance'])
display(df.style)
print("MEDIAN:")
print(df.median(axis = 0))
gan_data = np.array(gan_data)
gan_median = median(gan_data[:,1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_495d9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >Euclidean Distance</th>
#       <th class="col_heading level0 col3" >Manhattan Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_495d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_495d9_row0_col0" class="data row0 col0" >0.032024</td>
#       <td id="T_495d9_row0_col1" class="data row0 col1" >0.141618</td>
#       <td id="T_495d9_row0_col2" class="data row0 col2" >5.658944</td>
#       <td id="T_495d9_row0_col3" class="data row0 col3" >141.617562</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_495d9_row1_col0" class="data row1 col0" >0.038808</td>
#       <td id="T_495d9_row1_col1" class="data row1 col1" >0.148930</td>
#       <td id="T_495d9_row1_col2" class="data row1 col2" >6.229517</td>
#       <td id="T_495d9_row1_col3" class="data row1 col3" >148.930467</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_495d9_row2_col0" class="data row2 col0" >0.014501</td>
#       <td id="T_495d9_row2_col1" class="data row2 col1" >0.095140</td>
#       <td id="T_495d9_row2_col2" class="data row2 col2" >3.807997</td>
#       <td id="T_495d9_row2_col3" class="data row2 col3" >95.139774</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_495d9_row3_col0" class="data row3 col0" >0.031357</td>
#       <td id="T_495d9_row3_col1" class="data row3 col1" >0.140683</td>
#       <td id="T_495d9_row3_col2" class="data row3 col2" >5.599647</td>
#       <td id="T_495d9_row3_col3" class="data row3 col3" >140.683211</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_495d9_row4_col0" class="data row4 col0" >0.017540</td>
#       <td id="T_495d9_row4_col1" class="data row4 col1" >0.104097</td>
#       <td id="T_495d9_row4_col2" class="data row4 col2" >4.188051</td>
#       <td id="T_495d9_row4_col3" class="data row4 col3" >104.096956</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_495d9_row5_col0" class="data row5 col0" >0.020853</td>
#       <td id="T_495d9_row5_col1" class="data row5 col1" >0.115023</td>
#       <td id="T_495d9_row5_col2" class="data row5 col2" >4.566480</td>
#       <td id="T_495d9_row5_col3" class="data row5 col3" >115.022877</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_495d9_row6_col0" class="data row6 col0" >0.027961</td>
#       <td id="T_495d9_row6_col1" class="data row6 col1" >0.127868</td>
#       <td id="T_495d9_row6_col2" class="data row6 col2" >5.287734</td>
#       <td id="T_495d9_row6_col3" class="data row6 col3" >127.867710</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_495d9_row7_col0" class="data row7 col0" >0.016682</td>
#       <td id="T_495d9_row7_col1" class="data row7 col1" >0.102426</td>
#       <td id="T_495d9_row7_col2" class="data row7 col2" >4.084319</td>
#       <td id="T_495d9_row7_col3" class="data row7 col3" >102.426061</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_495d9_row8_col0" class="data row8 col0" >0.022928</td>
#       <td id="T_495d9_row8_col1" class="data row8 col1" >0.117354</td>
#       <td id="T_495d9_row8_col2" class="data row8 col2" >4.788246</td>
#       <td id="T_495d9_row8_col3" class="data row8 col3" >117.354068</td>
#     </tr>
#     <tr>
#       <th id="T_495d9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_495d9_row9_col0" class="data row9 col0" >0.016888</td>
#       <td id="T_495d9_row9_col1" class="data row9 col1" >0.101778</td>
#       <td id="T_495d9_row9_col2" class="data row9 col2" >4.109421</td>
#       <td id="T_495d9_row9_col3" class="data row9 col3" >101.777905</td>
#     </tr>
#   </tbody>
# </table>
# MEDIAN:
# MSE                     0.021890
# MAE                     0.116188
# Euclidean Distance      4.677363
# Manhattan Distance    116.188472
# dtype: float64

# %%
book = sb.read_notebooks("./Output_B")
abc_mae = []
abc_mae_skip = []
abc_mae_mean = []
abc_mae_skip_mean = []
abc_weights = []
prior_model = []
abc_pre_generator = []

for nb in book.notebooks:
    metrics1 = np.array(nb.scraps['ABC_GAN_1 Metrics'].data)
    metrics3 = np.array(nb.scraps['ABC_GAN_3 Metrics'].data)    
    #Divide data according to parameters 
    for j in range(100):
        abc_mae.append(metrics1[1,j])
        abc_mae_skip.append(metrics3[1,j])
    abc_weights.append(nb.scraps['Skip Connection Weight'].data)
    prior_model.append(nb.scraps['Prior Model MAE'].data)
    abc_pre_generator.append(nb.scraps['Pre-generator MAE'].data)
    abc_mae_skip_mean.append(mean(metrics3[1,:]))
    abc_mae_mean.append(mean(metrics1[1,:]))

# %%
data = []
data_median_stats = []
for j in range(len(abc_weights)):
    data.append([prior_model[j],
                    abc_pre_generator[j],abc_weights[j],abc_mae_mean[j],abc_mae_skip_mean[j]])

df = pd.DataFrame(data, columns = ['Baseline','Prior Model','Weight','ABC_GAN','Skip_GAN'])
data_median_stats = [gan_median,df['Baseline'].median(),df['Prior Model'].median(), df['ABC_GAN'].median(), df['Skip_GAN'].median(),
                    df['Weight'].median()]            
df
# Out:
#     Baseline  Prior Model    Weight   ABC_GAN   Skip_GAN
# 0  13.546561    13.560030  0.000000  6.055869  13.540159
# 1  13.546561    13.591385  0.000000  1.377813  13.488199
# 2  13.546561    13.583307  0.064321  2.086893   7.022256
# 3  13.546561    13.574031  0.158704  2.128897   4.085192
# 4  13.546561    13.563138  0.000000  1.491501  13.704691
# 5  13.546561    13.582231  0.086598  1.485360   7.492197
# 6  13.546561    13.565276  0.000000  1.854673  13.079328
# 7  13.546561    13.579877  0.082608  2.268575   3.217496
# 8  13.546561    13.556756  0.220040  1.724187   1.667382
# 9  13.546561    13.571474  0.000000  1.430494  14.060422

# %%
data_median_stats = np.reshape(data_median_stats,(1,6))
median_output = pd.DataFrame(data_median_stats,columns=['GAN','Baseline','Prior Model','ABC_GAN','Skip_GAN','Weight'])
median_output.head()
# Out:
#         GAN   Baseline  Prior Model  ABC_GAN   Skip_GAN   Weight
# 0  0.116188  13.546561    13.572752  1.78943  10.285762  0.03216
