# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import scrapbook as sb 
import pandas as pd
import numpy as np 
import seaborn as sns 
import numpy as np
from statistics import mean, median
import matplotlib.pyplot as plt

# %%
book = sb.read_notebooks("./GAN_Output")
gan_data = []
gan_mse = []
for nb in book.notebooks:
    metrics = nb.scraps['GAN_1 Metrics'].data
    for i in range(1000):
        gan_mse.append(metrics[0][i])
    nbList = [nb.scraps['GAN Model MSE'].data,
              nb.scraps['GAN Model MAE'].data,
              nb.scraps['GAN Model Euclidean distance'].data,
              nb.scraps['GAN Model Manhattan Distance'].data]        
    gan_data.append(nbList)
    
df = pd.DataFrame(gan_data, columns = ['MSE','MAE','Euclidean Distance','Manhattan Distance'])
display(df.style)
print("MEDIAN:")
print(df.median(axis = 0))
gan_data = np.array(gan_data)
gan_median = median(gan_data[:,1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5511_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MSE</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >Euclidean Distance</th>
#       <th class="col_heading level0 col3" >Manhattan Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5511_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5511_row0_col0" class="data row0 col0" >0.018705</td>
#       <td id="T_c5511_row0_col1" class="data row0 col1" >0.107268</td>
#       <td id="T_c5511_row0_col2" class="data row0 col2" >0.611349</td>
#       <td id="T_c5511_row0_col3" class="data row0 col3" >2.145360</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5511_row1_col0" class="data row1 col0" >0.031234</td>
#       <td id="T_c5511_row1_col1" class="data row1 col1" >0.154468</td>
#       <td id="T_c5511_row1_col2" class="data row1 col2" >0.789314</td>
#       <td id="T_c5511_row1_col3" class="data row1 col3" >3.089368</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5511_row2_col0" class="data row2 col0" >0.020432</td>
#       <td id="T_c5511_row2_col1" class="data row2 col1" >0.110003</td>
#       <td id="T_c5511_row2_col2" class="data row2 col2" >0.638903</td>
#       <td id="T_c5511_row2_col3" class="data row2 col3" >2.200066</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5511_row3_col0" class="data row3 col0" >0.031270</td>
#       <td id="T_c5511_row3_col1" class="data row3 col1" >0.140756</td>
#       <td id="T_c5511_row3_col2" class="data row3 col2" >0.790270</td>
#       <td id="T_c5511_row3_col3" class="data row3 col3" >2.815116</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5511_row4_col0" class="data row4 col0" >0.020575</td>
#       <td id="T_c5511_row4_col1" class="data row4 col1" >0.117167</td>
#       <td id="T_c5511_row4_col2" class="data row4 col2" >0.640923</td>
#       <td id="T_c5511_row4_col3" class="data row4 col3" >2.343339</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5511_row5_col0" class="data row5 col0" >0.017158</td>
#       <td id="T_c5511_row5_col1" class="data row5 col1" >0.099177</td>
#       <td id="T_c5511_row5_col2" class="data row5 col2" >0.585079</td>
#       <td id="T_c5511_row5_col3" class="data row5 col3" >1.983549</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5511_row6_col0" class="data row6 col0" >0.030613</td>
#       <td id="T_c5511_row6_col1" class="data row6 col1" >0.142436</td>
#       <td id="T_c5511_row6_col2" class="data row6 col2" >0.782129</td>
#       <td id="T_c5511_row6_col3" class="data row6 col3" >2.848719</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c5511_row7_col0" class="data row7 col0" >0.044656</td>
#       <td id="T_c5511_row7_col1" class="data row7 col1" >0.160835</td>
#       <td id="T_c5511_row7_col2" class="data row7 col2" >0.944283</td>
#       <td id="T_c5511_row7_col3" class="data row7 col3" >3.216692</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c5511_row8_col0" class="data row8 col0" >0.015738</td>
#       <td id="T_c5511_row8_col1" class="data row8 col1" >0.105804</td>
#       <td id="T_c5511_row8_col2" class="data row8 col2" >0.560543</td>
#       <td id="T_c5511_row8_col3" class="data row8 col3" >2.116071</td>
#     </tr>
#     <tr>
#       <th id="T_c5511_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c5511_row9_col0" class="data row9 col0" >0.023628</td>
#       <td id="T_c5511_row9_col1" class="data row9 col1" >0.129507</td>
#       <td id="T_c5511_row9_col2" class="data row9 col2" >0.687138</td>
#       <td id="T_c5511_row9_col3" class="data row9 col3" >2.590142</td>
#     </tr>
#   </tbody>
# </table>
# MEDIAN:
# MSE                   0.022101
# MAE                   0.123337
# Euclidean Distance    0.664030
# Manhattan Distance    2.466740
# dtype: float64

# %%
book = sb.read_notebooks("./Output")
abc_mae = []
abc_mae_skip = []
abc_mae_mean = []
abc_mae_skip_mean = []
abc_weights = []
prior_model = []
abc_pre_generator = []

for nb in book.notebooks:
    metrics1 = np.array(nb.scraps['ABC_GAN_1 Metrics'].data)
    metrics3 = np.array(nb.scraps['ABC_GAN_3 Metrics'].data)    
    #Divide data according to parameters 
    for j in range(100):
        abc_mae.append(metrics1[1,j])
        abc_mae_skip.append(metrics3[1,j])
    abc_weights.append(nb.scraps['Skip Connection Weight'].data)
    prior_model.append(nb.scraps['Prior Model MAE'].data)
    abc_pre_generator.append(nb.scraps['Pre-generator MAE'].data)
    abc_mae_skip_mean.append(mean(metrics3[1,:]))
    abc_mae_mean.append(mean(metrics1[1,:]))

# %%
data = []
data_median_stats = []
for j in range(len(abc_weights)):
    data.append([prior_model[j],
                    abc_pre_generator[j],abc_weights[j],abc_mae_mean[j],abc_mae_skip_mean[j]])

df = pd.DataFrame(data, columns = ['Baseline','Prior Model','Weight','ABC_GAN','Skip_GAN'])
data_median_stats = [gan_median,df['Baseline'].median(),df['Prior Model'].median(), df['ABC_GAN'].median(), df['Skip_GAN'].median(),
                    df['Weight'].median()]            
df
# Out:
#     Baseline  Prior Model    Weight   ABC_GAN  Skip_GAN
# 0  13.790332    13.737838  0.317345  0.089058  0.265178
# 1  13.790332    13.873874  0.461422  0.114848  0.128313
# 2  13.790332    13.899607  0.119242  0.106495  0.483028
# 3  13.790332    13.728219  0.412132  0.125243  0.237572
# 4  13.790332    13.701350  0.644324  0.111451  0.123806
# 5  13.790332    13.783819  0.105364  0.086651  0.118931
# 6  13.790332    13.900889  0.622748  0.119869  0.070613
# 7  13.790332    13.958999  0.916767  0.119077  0.128073
# 8  13.790332    13.800587  0.603862  0.138814  0.139723
# 9  13.790332    13.856106  0.873693  0.171248  0.124695

# %%
data_median_stats = np.reshape(data_median_stats,(1,6))
median_output = pd.DataFrame(data_median_stats,columns=['GAN','Baseline','Prior Model','ABC_GAN','Skip_GAN','Weight'])
median_output.head()
# Out:
#         GAN   Baseline  Prior Model   ABC_GAN  Skip_GAN    Weight
# 0  0.123337  13.790332    13.828347  0.116962  0.128193  0.532642
